# %%
# %reset -f

# %%
import os
import random
import re
from pathlib import Path
import numpy as np
import pandas as pd
from scipy.spatial.distance import cdist, pdist, squareform
from tqdm import tqdm

# %%
PROJ = Path(os.path.realpath("."))
ROOT = PROJ.parent
DATA = ROOT / "data"

# %%
# Read embeddings
clas_a = pd.read_parquet(DATA / "intermediate/clas_a_vec.parquet")
clas_b_list = ["HS2", "HS4", "NAICS2", "NAICS4"]
clas_b_dfs = [
    pd.read_parquet(DATA / f"intermediate/clas_b_vec_{x}.parquet") for x in clas_b_list
]
clas_a.head()
# Out:
#                                                  0         1         2  \
# clas_a_title                 clas_a_code
# Business Support Services    a0          -0.025925  0.025082  0.012210
# Fishing                      a1           0.067962  0.046946  0.048757
# Agriculture Employment       a2           0.008636  0.021638  0.011066
# Animal production            a3           0.036750  0.033058  0.018890
# Support activities of Mining a4          -0.017894  0.035146  0.002398
#
#                                                  3         4         5  \
# clas_a_title                 clas_a_code
# Business Support Services    a0           0.041680 -0.037457  0.041801
# Fishing                      a1           0.081487 -0.025844  0.041846
# Agriculture Employment       a2           0.013775  0.001630  0.020510
# Animal production            a3           0.080253  0.013234 -0.004848
# Support activities of Mining a4           0.047889 -0.005247  0.007037
#
#                                                  6         7         8  \
# clas_a_title                 clas_a_code
# Business Support Services    a0           0.055334  0.005141 -0.022281
# Fishing                      a1           0.052490 -0.045384  0.019322
# Agriculture Employment       a2           0.035688  0.008609  0.042362
# Animal production            a3           0.049736 -0.008246 -0.018134
# Support activities of Mining a4           0.041748 -0.031951  0.020205
#
#                                                  9  ...       290       291  \
# clas_a_title                 clas_a_code            ...
# Business Support Services    a0           0.001679  ...  0.030224  0.034443
# Fishing                      a1          -0.050553  ... -0.040666 -0.004089
# Agriculture Employment       a2           0.003880  ... -0.000912  0.053520
# Animal production            a3           0.019848  ... -0.029893  0.039475
# Support activities of Mining a4          -0.021872  ...  0.014639  0.013979
#
#                                                292       293       294  \
# clas_a_title                 clas_a_code
# Business Support Services    a0          -0.018788  0.030350  0.011706
# Fishing                      a1          -0.001307  0.025173 -0.010149
# Agriculture Employment       a2          -0.024568  0.040491  0.054232
# Animal production            a3          -0.038676  0.035650  0.064141
# Support activities of Mining a4          -0.018705  0.036255  0.039297
#
#                                                295       296       297  \
# clas_a_title                 clas_a_code
# Business Support Services    a0           0.009458  0.005382  0.043995
# Fishing                      a1          -0.046725 -0.110870  0.111892
# Agriculture Employment       a2          -0.031612 -0.000425  0.036069
# Animal production            a3          -0.022897 -0.034500  0.088468
# Support activities of Mining a4          -0.005247  0.022188  0.051874
#
#                                                298       299
# clas_a_title                 clas_a_code
# Business Support Services    a0          -0.007689  0.015419
# Fishing                      a1          -0.013310 -0.068479
# Agriculture Employment       a2           0.033190  0.009171
# Animal production            a3           0.039201  0.015250
# Support activities of Mining a4           0.015406  0.001576
#
# [5 rows x 300 columns]

# %%
def get_topn(clas_a, clas_b, nlargest=5):
    similarity_df = pd.DataFrame(
        1 - cdist(clas_a.values, clas_b.values, metric="cosine"),
        index=clas_a.index,
        columns=clas_b.index,
    )
    order = np.argsort(-similarity_df.values, axis=1)[:, :nlargest]
    clas_b_codes = [x for x, y in similarity_df.columns]
    clas_b_names = [y for x, y in similarity_df.columns]
    result_names = pd.DataFrame(
        np.array(clas_b_names)[order],
        columns=["top{}".format(i) for i in range(1, nlargest + 1)],
        index=similarity_df.index,
    )
    result_codes = pd.DataFrame(
        np.array(clas_b_codes)[order],
        columns=["top{}".format(i) for i in range(1, nlargest + 1)],
        index=similarity_df.index,
    )
    return result_codes, result_names

# %%
for clas_b, clas_b_type in zip(clas_b_dfs, clas_b_list):
    nlargest = 5
    topn_codes, topn_titles = get_topn(clas_a, clas_b, nlargest)
    topn_codes.to_csv(DATA / f"processed/top{str(nlargest)}_codes_{clas_b_type}.csv", index=True)
    topn_titles.to_csv(DATA / f"processed/top{str(nlargest)}_titles_{clas_b_type}.csv", index=True)

# %%
topn_titles.head()
# Out:
#                                                                                        top1  \
# clas_a_title                 clas_a_code
# Business Support Services    a0                                   Business Support Services
# Fishing                      a1                                                     Fishing
# Agriculture Employment       a2           Agriculture, Construction, and Mining Machiner...
# Animal production            a3                                     Other Animal Production
# Support activities of Mining a4                               Support Activities for Mining
#
#                                                                         top2  \
# clas_a_title                 clas_a_code
# Business Support Services    a0                       Other Support Services
# Fishing                      a1                         Hunting and Trapping
# Agriculture Employment       a2                          Hog and Pig Farming
# Animal production            a3           Animal Slaughtering and Processing
# Support activities of Mining a4              Support Activities for Forestry
#
#                                                                                        top3  \
# clas_a_title                 clas_a_code
# Business Support Services    a0                                Educational Support Services
# Fishing                      a1                                                 Aquaculture
# Agriculture Employment       a2                                         Employment Services
# Animal production            a3                    Support Activities for Animal Production
# Support activities of Mining a4           Agriculture, Construction, and Mining Machiner...
#
#                                                                                top4  \
# clas_a_title                 clas_a_code
# Business Support Services    a0                         Facilities Support Services
# Fishing                      a1                                 Hog and Pig Farming
# Agriculture Employment       a2                     Support Activities for Forestry
# Animal production            a3                           Animal Food Manufacturing
# Support activities of Mining a4           Support Activities for Air Transportation
#
#                                                                                        top5
# clas_a_title                 clas_a_code
# Business Support Services    a0                                  Other Information Services
# Fishing                      a1           Deep Sea, Coastal, and Great Lakes Water Trans...
# Agriculture Employment       a2                                 Cattle Ranching and Farming
# Animal production            a3                                  Poultry and Egg Production
# Support activities of Mining a4                 Other Support Activities for Transportation
